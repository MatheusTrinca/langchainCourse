# %% [markdown]
# ### ChromaDB

# %% [markdown]
# ##### adding texts

# %%
from langchain_chroma import Chroma
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from dotenv import load_dotenv

load_dotenv()
embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")

vector_store = Chroma(
    collection_name="my-text-docs",
    embedding_function=embeddings,
    persist_directory="./databases/chroma_langchain_db",
)

text_docs = ["Hello World", "World Economy"]

vector_store.add_texts(texts=text_docs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 6
#       3 from dotenv import load_dotenv
#       5 load_dotenv()
# ----> 6 embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")
#       8 vector_store = Chroma(
#       9     collection_name="my-text-docs",
#      10     embedding_function=embeddings,
#      11     persist_directory="./databases/chroma_langchain_db",
#      12 )
#      14 text_docs = ["Hello World", "World Economy"]
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\langchain_google_genai\embeddings.py:240, in GoogleGenerativeAIEmbeddings._initialize_client(self)
#     234         msg = (
#     235             "API key required for Gemini Developer API. Provide api_key "
#     236             "parameter or set GOOGLE_API_KEY/GEMINI_API_KEY environment "
#     237             "variable."
#     238         )
#     239         raise ValueError(msg)
# --> 240     self.client = Client(api_key=google_api_key, http_options=http_options)
#     242 return self
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\google\genai\client.py:395, in Client.__init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     392   else:
#     393     http_options = HttpOptions(base_url=base_url)
# --> 395 self._api_client = self._get_api_client(
#     396     vertexai=vertexai,
#     397     api_key=api_key,
#     398     credentials=credentials,
#     399     project=project,
#     400     location=location,
#     401     debug_config=self._debug_config,
#     402     http_options=http_options,
#     403 )
#     405 self._aio = AsyncClient(self._api_client)
#     406 self._models = Models(self._api_client)
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\google\genai\client.py:443, in Client._get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     426 if debug_config and debug_config.client_mode in [
#     427     'record',
#     428     'replay',
#     429     'auto',
#     430 ]:
#     431   return ReplayApiClient(
#     432       mode=debug_config.client_mode,  # type: ignore[arg-type]
#     433       replay_id=debug_config.replay_id,  # type: ignore[arg-type]
#    (...)    440       http_options=http_options,
#     441   )
# --> 443 return BaseApiClient(
#     444     vertexai=vertexai,
#     445     api_key=api_key,
#     446     credentials=credentials,
#     447     project=project,
#     448     location=location,
#     449     http_options=http_options,
#     450 )
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\google\genai\_api_client.py:732, in BaseApiClient.__init__(self, vertexai, api_key, credentials, project, location, http_options)
#     729 self._aiohttp_session: Optional[aiohttp.ClientSession] = None
#     731 retry_kwargs = retry_args(self._http_options.retry_options)
# --> 732 self._websocket_ssl_ctx = self._ensure_websocket_ssl_ctx(self._http_options)
#     733 self._retry = tenacity.Retrying(**retry_kwargs)
#     734 self._async_retry = tenacity.AsyncRetrying(**retry_kwargs)
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\google\genai\_api_client.py:927, in BaseApiClient._ensure_websocket_ssl_ctx(options)
#     919 ctx = async_args.get(verify) if async_args else None
#     921 if not ctx:
#     922   # Initialize the SSL context for the httpx client.
#     923   # Unlike requests, the aiohttp package does not automatically pull in the
#     924   # environment variables SSL_CERT_FILE or SSL_CERT_DIR. They need to be
#     925   # enabled explicitly. Instead of 'verify' at client level in httpx,
#     926   # aiohttp uses 'ssl' at request level.
# --> 927   ctx = ssl.create_default_context(
#     928       cafile=os.environ.get('SSL_CERT_FILE', certifi.where()),
#     929       capath=os.environ.get('SSL_CERT_DIR'),
#     930   )
#     932 def _maybe_set(
#     933     args: Optional[_common.StringDict],
#     934     ctx: ssl.SSLContext,
#     935 ) -> _common.StringDict:
#     936   """Sets the SSL context in the client args if not set.
#     937
#     938   Does not override the SSL context if it is already set.
#    (...)    945     The client args with the SSL context included.
#     946   """
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:708, in create_default_context(purpose, cafile, capath, cadata)
#     705     raise ValueError(purpose)
#     707 if cafile or capath or cadata:
# --> 708     context.load_verify_locations(cafile, capath, cadata)
#     709 elif context.verify_mode != CERT_NONE:
#     710     # no explicit cafile, capath or cadata but the verify mode is
#     711     # CERT_OPTIONAL or CERT_REQUIRED. Let's try to load default system
#     712     # root CA certificates for the given purpose. This may fail silently.
#     713     context.load_default_certs(purpose)
#
# KeyboardInterrupt:

# %%
more_text_docs = ["World Health", "World Crisis"]

vector_store.add_texts(texts=more_text_docs)
# Out:
# ['dd2bd129-968f-4790-9ea8-f5f1018c072a',
#  '17490069-364b-48b8-8ae1-1dd5d7574e8a']

# %%
print(vector_store.get()['documents'])
# Out:
# ['Hello World', 'World Economy', 'Data Science', 'Machine Learning', 'Hello World', 'World Economy', 'World Health', 'World Crisis']

# %% [markdown]
# ##### Adding documents

# %%
from langchain_chroma import Chroma
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_core.documents import Document
from dotenv import load_dotenv

load_dotenv()
embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")

vector_store = Chroma(
    collection_name="my-text-docs",
    embedding_function=embeddings,
    persist_directory="./databases/chroma_langchain_db",
)

documents = [
    Document(page_content="Hello World", metadata={"source": "source1"}),
    Document(page_content="World Economy", metadata={"source": "source2"}),
    Document(page_content="Data Science", metadata={"source": "source3"}),
    Document(page_content="Machine Learning", metadata={"source": "source4"}),
]

vector_store.add_documents(documents)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 22
#       9 vector_store = Chroma(
#      10     collection_name="my-text-docs",
#      11     embedding_function=embeddings,
#      12     persist_directory="./databases/chroma_langchain_db",
#      13 )
#      15 documents = [
#      16     Document(page_content="Hello World", metadata={"source": "source1"}),
#      17     Document(page_content="World Economy", metadata={"source": "source2"}),
#      18     Document(page_content="Data Science", metadata={"source": "source3"}),
#      19     Document(page_content="Machine Learning", metadata={"source": "source4"}),
#      20 ]
# ---> 22 vector_store.add_documents(documents)
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\langchain_core\vectorstores\base.py:257, in VectorStore.add_documents(self, documents, **kwargs)
#     255     texts = [doc.page_content for doc in documents]
#     256     metadatas = [doc.metadata for doc in documents]
# --> 257     return self.add_texts(texts, metadatas, **kwargs)
#     258 msg = (
#     259     f"`add_documents` and `add_texts` has not been implemented "
#     260     f"for {self.__class__.__name__} "
#     261 )
#     262 raise NotImplementedError(msg)
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\langchain_chroma\vectorstores.py:627, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     625 texts = list(texts)
#     626 if self._embedding_function is not None:
# --> 627     embeddings = self._embedding_function.embed_documents(texts)
#     628 if metadatas:
#     629     # fill metadatas with empty dicts if somebody
#     630     # did not specify metadata for all texts
#     631     length_diff = len(texts) - len(metadatas)
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\langchain_google_genai\embeddings.py:378, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     371 config = self._build_config(
#     372     task_type=effective_task_type,
#     373     title=title,
#     374     output_dimensionality=output_dimensionality,
#     375 )
#     377 try:
# --> 378     result = self.client.models.embed_content(
#     379         model=self.model,
#     380         contents=batch,
#     381         config=config,
#     382     )
#     383 except ClientError as e:
#     384     msg = f"Error embedding content ({e.status}): {e}"
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\google\genai\models.py:4194, in Models.embed_content(self, model, contents, config)
#    4191 request_dict = _common.convert_to_dict(request_dict)
#    4192 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4194 response = self._api_client.request(
#    4195     'post', path, request_dict, http_options
#    4196 )
#    4198 response_dict = {} if not response.body else json.loads(response.body)
#    4200 if self._api_client.vertexai:
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\google\genai\_api_client.py:1388, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1378 def request(
#    1379     self,
#    1380     http_method: str,
#    (...)   1383     http_options: Optional[HttpOptionsOrDict] = None,
#    1384 ) -> SdkHttpResponse:
#    1385   http_request = self._build_request(
#    1386       http_method, path, request_dict, http_options
#    1387   )
# -> 1388   response = self._request(http_request, http_options, stream=False)
#    1389   response_body = (
#    1390       response.response_stream[0] if response.response_stream else ''
#    1391   )
#    1392   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\google\genai\_api_client.py:1224, in BaseApiClient._request(self, http_request, http_options, stream)
#    1221     retry = tenacity.Retrying(**retry_kwargs)
#    1222     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1224 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\tenacity\__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\google\genai\_api_client.py:1194, in BaseApiClient._request_once(self, http_request, stream)
#    1190   return HttpResponse(
#    1191       response.headers, response if stream else [response.text]
#    1192   )
#    1193 else:
# -> 1194   response = self._httpx_client.request(
#    1195       method=http_request.method,
#    1196       url=http_request.url,
#    1197       headers=http_request.headers,
#    1198       content=data,
#    1199       timeout=http_request.timeout,
#    1200   )
#    1201   errors.APIError.raise_for_response(response)
#    1202   return HttpResponse(
#    1203       response.headers, response if stream else [response.text]
#    1204   )
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpx\_client.py:928, in Client.send(self, request, stream, auth, follow_redirects)
#     926 except BaseException as exc:
#     927     response.close()
# --> 928     raise exc
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpx\_client.py:922, in Client.send(self, request, stream, auth, follow_redirects)
#     920 try:
#     921     if not stream:
# --> 922         response.read()
#     924     return response
#     926 except BaseException as exc:
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpx\_models.py:881, in Response.read(self)
#     877 """
#     878 Read and return the response content.
#     879 """
#     880 if not hasattr(self, "_content"):
# --> 881     self._content = b"".join(self.iter_bytes())
#     882 return self._content
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\MatheusFelipeTrinca\Dev\langchainCourse\venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1233, in SSLSocket.recv(self, buflen, flags)
#    1229     if flags != 0:
#    1230         raise ValueError(
#    1231             "non-zero flags not allowed in calls to recv() on %s" %
#    1232             self.__class__)
# -> 1233     return self.read(buflen)
#    1234 else:
#    1235     return super().recv(buflen, flags)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1106, in SSLSocket.read(self, len, buffer)
#    1104         return self._sslobj.read(len, buffer)
#    1105     else:
# -> 1106         return self._sslobj.read(len)
#    1107 except SSLError as x:
#    1108     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ##### similarity search

# %%
vector_store.similarity_search("Data", k=2)
# Out:
# [Document(id='b15782a0-7d2a-44ef-8751-5ffd5cbd5042', metadata={'source': 'source3'}, page_content='Data Science'),
#  Document(id='f72d77e4-1e59-43c2-a806-c63cd5fe7993', metadata={'source': 'source4'}, page_content='Machine Learning')]

# %%
vector_store.similarity_search("World", k=2)
# Out:
# [Document(id='165b81c9-d03d-47b9-991a-933ef144c9d9', metadata={'source': 'source2'}, page_content='World Economy'),
#  Document(id='0a6a4e79-180e-427f-b849-accbacb8e586', metadata={'source': 'source1'}, page_content='Hello World')]

# %%
# vector_store.delete_collection()

# %% [markdown]
# ### FAISS

# %% [markdown]
# ##### adding texts

# %%
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS

load_dotenv()
embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")

embedding_dim = len(embeddings.embed_query("test"))
index = faiss.IndexFlatL2(embedding_dim)

vector_store_1 = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)

# %%
vector_store_1.add_texts(texts=["Hello World", "World Economy"])
# Out:
# ['528eea84-376b-4429-b2d4-87211b85f2c3',
#  '803180b9-77f7-463d-978e-2f95d4045e2a']

# %%
result_1 = list(vector_store_1.docstore._dict.values())

for doc in result_1:
    print(doc)
# Out:
# page_content='Hello World'
# page_content='World Economy'

# %%
vector_store_2 = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)

# %%
vector_store_2.add_texts(texts=["Hello World 2", "World Economy 2"])
# Out:
# ['cdf0452a-5718-4f04-aa08-671aef3f3b30',
#  '81d7616f-5330-4046-8b4d-40b750b6146c']

# %%
result_2 = list(vector_store_2.docstore._dict.values())

for doc in result_2:
    print(doc)
# Out:
# page_content='Hello World 2'
# page_content='World Economy 2'

# %%
# vector_store.similarity_search("World", k=2)
# Out:
# [Document(id='360896e3-42bd-4b0a-9d4a-8664ce197e47', metadata={}, page_content='World Economy'),
#  Document(id='3c6af570-4529-47b8-84fb-a6e8825c78a3', metadata={}, page_content='World Economy 2')]

# %%
# del vector_store_2

# %%
vector_store_1.merge_from(vector_store_2)

# %%
result_3 = list(vector_store_1.docstore._dict.values())

for doc in result_3:
    print(doc)
# Out:
# page_content='Hello World'
# page_content='World Economy'
# page_content='Hello World 2'
# page_content='World Economy 2'

# %% [markdown]
# ##### adding documents

# %%
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS

load_dotenv()
embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")

embedding_dim = len(embeddings.embed_query("test"))
index = faiss.IndexFlatL2(embedding_dim)

doc_vector_store = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)

# %%
documents = [
    Document(page_content="Hello World", metadata={"source": "source1"}),
    Document(page_content="World Economy", metadata={"source": "source2"}),
    Document(page_content="Data Science", metadata={"source": "source3"}),
    Document(page_content="Machine Learning", metadata={"source": "source4"}),
]

doc_vector_store.add_documents(documents)
# Out:
# ['b4c02270-da25-4b4a-bd42-2b164a068c4f',
#  '6b496f9b-7ff4-46c2-a301-990d8609fa8e',
#  '251065cb-04f7-430a-99f6-88d3c3c88cbd',
#  'd6eb6bfd-ff59-4491-81e8-5b060387ab80']

# %% [markdown]
# ##### similarity search

# %%
doc_vector_store.similarity_search("Data", k=2)

for i in doc_vector_store.docstore._dict.values():
    print(i)
# Out:
# page_content='Hello World' metadata={'source': 'source1'}
# page_content='World Economy' metadata={'source': 'source2'}
# page_content='Data Science' metadata={'source': 'source3'}
# page_content='Machine Learning' metadata={'source': 'source4'}
